# %% [markdown]
# # Introduction
#
# This is an EDA and regression model that will predict the Final weight

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/weight_change_dataset.csv')

# %% [markdown]
# to start I want to get an idea for each of the distributions I have throughout this dataset

# %%
df.head()
# Out:
#    Participant ID  Age Gender  Current Weight (lbs)  BMR (Calories)  \
# 0               1   56      M                 228.4          3102.3
# 1               2   46      F                 165.4          2275.5
# 2               3   32      F                 142.8          2119.4
# 3               4   25      F                 145.5          2181.3
# 4               5   38      M                 155.5          2463.8
#
#    Daily Calories Consumed  Daily Caloric Surplus/Deficit  \
# 0                   3916.0                          813.7
# 1                   3823.0                         1547.5
# 2                   2785.4                          666.0
# 3                   2587.3                          406.0
# 4                   3312.8                          849.0
#
#    Weight Change (lbs)  Duration (weeks) Physical Activity Level  \
# 0                  0.2                 1               Sedentary
# 1                  2.4                 6             Very Active
# ...

# %%
sns.histplot(x=df['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.countplot(x=df['Gender'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.histplot(x=df['Current Weight (lbs)'], kde=True)
# Out:
# <Axes: xlabel='Current Weight (lbs)', ylabel='Count'>

# %%
sns.histplot(x=df['BMR (Calories)'], kde=True)
# Out:
# <Axes: xlabel='BMR (Calories)', ylabel='Count'>

# %%
sns.histplot(x=df['Daily Calories Consumed'], kde=True)
# Out:
# <Axes: xlabel='Daily Calories Consumed', ylabel='Count'>

# %%
sns.histplot(x=df['Daily Caloric Surplus/Deficit'], kde=True)
# Out:
# <Axes: xlabel='Daily Caloric Surplus/Deficit', ylabel='Count'>

# %%
sns.histplot(x=df['Weight Change (lbs)'], kde=True)
# Out:
# <Axes: xlabel='Weight Change (lbs)', ylabel='Count'>

# %%
sns.countplot(x=df['Duration (weeks)'])
# Out:
# <Axes: xlabel='Duration (weeks)', ylabel='count'>

# %%
sns.countplot(x=df['Physical Activity Level'])
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='count'>

# %%
sns.countplot(x=df['Sleep Quality'])
# Out:
# <Axes: xlabel='Sleep Quality', ylabel='count'>

# %%
sns.countplot(x=df['Stress Level'])
# Out:
# <Axes: xlabel='Stress Level', ylabel='count'>
